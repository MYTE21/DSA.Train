# %%
def addition(n1):
    def add(n2):
        return n1 + n2
    return add


if __name__ == "__main__":
    ten_plus = addition(10)
    hundred_plus = addition(100)

    print(ten_plus(5))
    print(hundred_plus(20))
# Out:
# 15
# 120

# %%
one_plus = addition(1)

print(one_plus(1))
print(one_plus(2))
print(one_plus(5))
# Out:
# 2
# 3
# 6

# %%
def addition(n1):
    def add(n2):
        return n1 + n2
    return add


if __name__ == "__main__":
    one_plus = addition(1)
    print(one_plus(10))
    print(one_plus.__closure__)
    print(addition.__closure__)
# Out:
# 11
# (<cell at 0x000002A1F98D9FF0: int object at 0x00007FFD112703A8>,)
# None

# %%
 def addition(n1):
    def add(n2):
        return 1 + n2
    return add


if __name__ == "__main__":
    one_plus = addition(1)
    print(one_plus(10))
    print(one_plus.__closure__)
# Out:
# 11
# None
