# %%
one_plus = lambda x: x + 1

# %%
one_plus(3)
# Out:
# 4

# %%
one_plus(4)
# Out:
# 5

# %%
type(one_plus)
# Out:
# function

# %%
add = lambda x, y: x + y

# %%
add(3, 4)
# Out:
# 7

# %%
def addition(n1):
    return lambda n2: n1 + n2


if __name__ == "__main__":
    one_plus = addition(1)
    print(one_plus(10))
# Out:
# 11
