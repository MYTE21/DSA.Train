# %%
class A:
    def fnc(self):
        print("Hello from A")


class B:
    def fnc(self):
        print("Hello from B")

# %%
class C(A, B):
    pass


obj = C()
obj.fnc()
# Out:
# Hello from A

# %%
class D(B, A):
    pass


obj = D()
obj.fnc()
# Out:
# Hello from B

# %%
D.mro()
# Out:
# [__main__.D, __main__.B, __main__.A, object]

# %%
C.mro()
# Out:
# [__main__.C, __main__.A, __main__.B, object]

# %% [markdown]
# # Question and Answer

# %%
class A:
    def hello(self):
        print("Hello From A")

# %% [markdown]
# Question - 1

# %%
class B(A):
    def hello(self):
        print("Hello From B")

# %%
class C(A):
    def hello(self):
        print("Hello From C")

# %%
class D(B, C):
    pass

# %%
if __name__ == "__main__":
    obj = D()
    obj.hello()
# Out:
# Hello From B

# %% [markdown]
# Question - 2

# %%
class B(A):
    def hello(self):
        print("Hello From B")

# %%
class C(A):
    pass

# %%
class D(B, C):
    pass

# %%
if __name__ == "__main__":
    obj = D()
    obj.hello()
# Out:
# Hello From B

# %% [markdown]
# Question - 3

# %%
class B(A):
    pass

# %%
class C(A):
    def hello(self):
        print("Hello From C")

# %%
class D(B, C):
    pass

# %%
if __name__ == "__main__":
    obj = D()
    obj.hello()
# Out:
# Hello From C
